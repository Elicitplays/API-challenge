# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 621

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = query_url+city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(query_url+city).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | queenstown
# Processing Record 2 of Set 1 | mont-tremblant
# Processing Record 3 of Set 1 | fale old settlement
# Processing Record 4 of Set 1 | vorkuta
# Processing Record 5 of Set 1 | adamstown
# Processing Record 6 of Set 1 | blackmans bay
# Processing Record 7 of Set 1 | chonchi
# Processing Record 8 of Set 1 | luanda
# Processing Record 9 of Set 1 | invercargill
# Processing Record 10 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 11 of Set 1 | cottonwood
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | agidel'
# City not found. Skipping...
# Processing Record 14 of Set 1 | kimbe
# Processing Record 15 of Set 1 | sao vicente
# Processing Record 16 of Set 1 | vilyuchinsk
# Processing Record 17 of Set 1 | beroroha
# Processing Record 18 of Set 1 | belmonte
# Processing Record 19 of Set 1 | hamilton
# Processing Record 20 of Set 1 | khandyga
# Processing Record 21 of Set 1 | port-aux-francais
# Processing Record 22 of Set 1 | miles city
# Processing Record 23 of Set 1 | puerto aysen
# Processing Record 24 of Set 1 | kodiak
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | alice springs
# Processing Record 27 of Set 1 | kushikino
# Processing Record 28 of Set 1 | encantado
# Processing Record 29 of Set 1 | olonkinbyen
# Processing Record 30 of Set 1 | kapa'a
# Processing Record 31 of Set 1 | crane
# Processing Record 32 of Set 1 | illela
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | isafjordur
# Processing Record 35 of Set 1 | nabire
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | cairns city
# City not found. Skipping...
# Processing Record 38 of Set 1 | colares
# Processing Record 39 of Set 1 | kalianget
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | ust-nera
# Processing Record 42 of Set 1 | vorgashor
# Processing Record 43 of Set 1 | eket
# Processing Record 44 of Set 1 | keflavik
# Processing Record 45 of Set 1 | edinburgh of the seven seas
# Processing Record 46 of Set 1 | karaton
# Processing Record 47 of Set 1 | pakur
# Processing Record 48 of Set 1 | lebu
# Processing Record 49 of Set 1 | uturoa
# Processing Record 50 of Set 1 | korla
# Processing Record 0 of Set 2 | thunder bay
# Processing Record 1 of Set 2 | vizinga
# Processing Record 2 of Set 2 | cerro de ortega
# Processing Record 3 of Set 2 | the bottom
# Processing Record 4 of Set 2 | college
# Processing Record 5 of Set 2 | aykhal
# Processing Record 6 of Set 2 | wabag
# Processing Record 7 of Set 2 | stanley
# Processing Record 8 of Set 2 | pechora
# Processing Record 9 of Set 2 | libreville
# Processing Record 10 of Set 2 | pointe-noire
# Processing Record 11 of Set 2 | mendoza
# Processing Record 12 of Set 2 | iskateley
# Processing Record 13 of Set 2 | colonia
# Processing Record 14 of Set 2 | aasiaat
# Processing Record 15 of Set 2 | cabinda
# Processing Record 16 of Set 2 | naze
# Processing Record 17 of Set 2 | villa la angostura
# Processing Record 18 of Set 2 | st. john's
# Processing Record 19 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 20 of Set 2 | puerto natales
# Processing Record 21 of Set 2 | waitangi
# Processing Record 22 of Set 2 | harper
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | wanning
# Processing Record 25 of Set 2 | atafu village
# Processing Record 26 of Set 2 | international falls
# Processing Record 27 of Set 2 | papatowai
# Processing Record 28 of Set 2 | anadyr
# Processing Record 29 of Set 2 | okha
# Processing Record 30 of Set 2 | inongo
# Processing Record 31 of Set 2 | northam
# Processing Record 32 of Set 2 | arenapolis
# Processing Record 33 of Set 2 | yanam
# Processing Record 34 of Set 2 | kapuskasing
# Processing Record 35 of Set 2 | bilibino
# Processing Record 36 of Set 2 | tiksi
# Processing Record 37 of Set 2 | tchintabaraden
# Processing Record 38 of Set 2 | ribeira grande
# Processing Record 39 of Set 2 | hawaiian paradise park
# Processing Record 40 of Set 2 | carnarvon
# Processing Record 41 of Set 2 | san juan del sur
# Processing Record 42 of Set 2 | copala
# Processing Record 43 of Set 2 | koulikoro
# Processing Record 44 of Set 2 | jieshi
# Processing Record 45 of Set 2 | clifton
# Processing Record 46 of Set 2 | usinsk
# Processing Record 47 of Set 2 | san antonio de pale
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | pariang
# City not found. Skipping...
# Processing Record 0 of Set 3 | plonsk
# Processing Record 1 of Set 3 | sola
# Processing Record 2 of Set 3 | saint-joseph
# Processing Record 3 of Set 3 | bathsheba
# Processing Record 4 of Set 3 | thompson
# Processing Record 5 of Set 3 | west island
# Processing Record 6 of Set 3 | ullal
# Processing Record 7 of Set 3 | kavieng
# Processing Record 8 of Set 3 | moyynkum
# Processing Record 9 of Set 3 | longyearbyen
# Processing Record 10 of Set 3 | jonacatepec
# Processing Record 11 of Set 3 | avarua
# Processing Record 12 of Set 3 | longboat key
# Processing Record 13 of Set 3 | sebastopol
# Processing Record 14 of Set 3 | san patricio
# Processing Record 15 of Set 3 | shilin
# Processing Record 16 of Set 3 | aswan
# Processing Record 17 of Set 3 | okhotsk
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | al 'amarah
# Processing Record 20 of Set 3 | dunedin
# Processing Record 21 of Set 3 | suva
# Processing Record 22 of Set 3 | shimoda
# Processing Record 23 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 24 of Set 3 | hasaki
# Processing Record 25 of Set 3 | saint-pierre
# Processing Record 26 of Set 3 | iqaluit
# Processing Record 27 of Set 3 | margaret river
# Processing Record 28 of Set 3 | barra de santo antonio
# Processing Record 29 of Set 3 | acarau
# Processing Record 30 of Set 3 | kudahuvadhoo
# Processing Record 31 of Set 3 | koubia
# Processing Record 32 of Set 3 | nova sintra
# Processing Record 33 of Set 3 | lobito
# Processing Record 34 of Set 3 | ilulissat
# Processing Record 35 of Set 3 | uribia
# Processing Record 36 of Set 3 | port mathurin
# Processing Record 37 of Set 3 | osmaniye
# Processing Record 38 of Set 3 | warah
# Processing Record 39 of Set 3 | kenai
# Processing Record 40 of Set 3 | narvik
# Processing Record 41 of Set 3 | bethel
# Processing Record 42 of Set 3 | klyuchi
# Processing Record 43 of Set 3 | ankang
# Processing Record 44 of Set 3 | bredasdorp
# Processing Record 45 of Set 3 | fortuna
# Processing Record 46 of Set 3 | mazagao
# Processing Record 47 of Set 3 | saipan
# Processing Record 48 of Set 3 | novodvinsk
# Processing Record 49 of Set 3 | grytviken
# Processing Record 0 of Set 4 | ebon
# Processing Record 1 of Set 4 | santa marta de ortigueira
# Processing Record 2 of Set 4 | nouadhibou
# Processing Record 3 of Set 4 | lembar
# City not found. Skipping...
# Processing Record 4 of Set 4 | wailua homesteads
# Processing Record 5 of Set 4 | fada
# Processing Record 6 of Set 4 | rishikesh
# Processing Record 7 of Set 4 | lamar
# Processing Record 8 of Set 4 | faya-largeau
# Processing Record 9 of Set 4 | inverloch
# Processing Record 10 of Set 4 | cabo san lucas
# Processing Record 11 of Set 4 | bubaque
# Processing Record 12 of Set 4 | itaituba
# Processing Record 13 of Set 4 | gogrial
# Processing Record 14 of Set 4 | zimatlan de alvarez
# Processing Record 15 of Set 4 | tolmezzo
# Processing Record 16 of Set 4 | garachico
# Processing Record 17 of Set 4 | leava
# Processing Record 18 of Set 4 | dalandzadgad
# Processing Record 19 of Set 4 | midvagur
# Processing Record 20 of Set 4 | flying fish cove
# Processing Record 21 of Set 4 | ust'-ilimsk
# Processing Record 22 of Set 4 | vila velha
# Processing Record 23 of Set 4 | sarykemer
# Processing Record 24 of Set 4 | daru
# Processing Record 25 of Set 4 | luderitz
# Processing Record 26 of Set 4 | bonthe
# Processing Record 27 of Set 4 | tlaltenango de sanchez roman
# Processing Record 28 of Set 4 | ojinaga
# Processing Record 29 of Set 4 | montegranaro
# Processing Record 30 of Set 4 | hermanus
# Processing Record 31 of Set 4 | hassi messaoud
# Processing Record 32 of Set 4 | mount gambier
# Processing Record 33 of Set 4 | north bend
# Processing Record 34 of Set 4 | pagar alam
# Processing Record 35 of Set 4 | remire-montjoly
# Processing Record 36 of Set 4 | revda
# Processing Record 37 of Set 4 | portland
# Processing Record 38 of Set 4 | tura
# Processing Record 39 of Set 4 | enewetak
# Processing Record 40 of Set 4 | toamasina
# Processing Record 41 of Set 4 | suai
# City not found. Skipping...
# Processing Record 42 of Set 4 | kerikeri
# Processing Record 43 of Set 4 | maubara
# City not found. Skipping...
# Processing Record 44 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 45 of Set 4 | sinabang
# Processing Record 46 of Set 4 | bel ombre
# Processing Record 47 of Set 4 | praia da vitoria
# Processing Record 48 of Set 4 | kavaratti
# Processing Record 49 of Set 4 | macau
# Processing Record 0 of Set 5 | rumphi
# Processing Record 1 of Set 5 | kingston
# Processing Record 2 of Set 5 | nkurenkuru
# City not found. Skipping...
# Processing Record 3 of Set 5 | kirakira
# Processing Record 4 of Set 5 | urengoy
# Processing Record 5 of Set 5 | clear lake
# Processing Record 6 of Set 5 | bodo
# Processing Record 7 of Set 5 | kamin-kashyrskyi
# Processing Record 8 of Set 5 | arkhangel'sk
# Processing Record 9 of Set 5 | aragarcas
# Processing Record 10 of Set 5 | undurkhaan
# Processing Record 11 of Set 5 | motygino
# Processing Record 12 of Set 5 | saint-philippe
# Processing Record 13 of Set 5 | tosontsengel
# Processing Record 14 of Set 5 | kalispell
# Processing Record 15 of Set 5 | constantia
# Processing Record 16 of Set 5 | shenjiamen
# Processing Record 17 of Set 5 | laguna
# Processing Record 18 of Set 5 | antofagasta
# Processing Record 19 of Set 5 | la passe
# Processing Record 20 of Set 5 | wanlaweyn
# Processing Record 21 of Set 5 | angaur state
# Processing Record 22 of Set 5 | tirebolu
# Processing Record 23 of Set 5 | verkh-tula
# Processing Record 24 of Set 5 | kruisfontein
# Processing Record 25 of Set 5 | whitehorse
# Processing Record 26 of Set 5 | machico
# Processing Record 27 of Set 5 | santa marta
# Processing Record 28 of Set 5 | howard springs
# Processing Record 29 of Set 5 | urangan
# Processing Record 30 of Set 5 | minas de marcona
# Processing Record 31 of Set 5 | trongsa
# Processing Record 32 of Set 5 | tadine
# Processing Record 33 of Set 5 | salalah
# Processing Record 34 of Set 5 | yarmouth
# Processing Record 35 of Set 5 | kiunga
# Processing Record 36 of Set 5 | pisco
# Processing Record 37 of Set 5 | tambo
# Processing Record 38 of Set 5 | chernyshevskiy
# Processing Record 39 of Set 5 | that phanom
# Processing Record 40 of Set 5 | ancud
# Processing Record 41 of Set 5 | namibe
# Processing Record 42 of Set 5 | katabu
# Processing Record 43 of Set 5 | gallivare
# City not found. Skipping...
# Processing Record 44 of Set 5 | zemio
# Processing Record 45 of Set 5 | stephenville
# Processing Record 46 of Set 5 | sitka
# Processing Record 47 of Set 5 | cable beach
# City not found. Skipping...
# Processing Record 48 of Set 5 | puerto ayora
# Processing Record 49 of Set 5 | cartagena
# Processing Record 0 of Set 6 | umba
# Processing Record 1 of Set 6 | naujoji akmene
# Processing Record 2 of Set 6 | makokou
# Processing Record 3 of Set 6 | utrik
# Processing Record 4 of Set 6 | caleta de carquin
# Processing Record 5 of Set 6 | mercedes
# Processing Record 6 of Set 6 | guerrero negro
# Processing Record 7 of Set 6 | cidreira
# Processing Record 8 of Set 6 | geraldton
# Processing Record 9 of Set 6 | mizdah
# Processing Record 10 of Set 6 | kaedi
# Processing Record 11 of Set 6 | port douglas
# Processing Record 12 of Set 6 | kedrovyy
# Processing Record 13 of Set 6 | voss
# Processing Record 14 of Set 6 | nar'yan-mar
# Processing Record 15 of Set 6 | arkalyk
# Processing Record 16 of Set 6 | qaqortoq
# Processing Record 17 of Set 6 | kangasniemi
# Processing Record 18 of Set 6 | bengkulu
# Processing Record 19 of Set 6 | luau
# Processing Record 20 of Set 6 | gueltat zemmour
# City not found. Skipping...
# Processing Record 21 of Set 6 | broken hill
# Processing Record 22 of Set 6 | vila franca do campo
# Processing Record 23 of Set 6 | bandarbeyla
# Processing Record 24 of Set 6 | el porvenir
# Processing Record 25 of Set 6 | helena valley southeast
# Processing Record 26 of Set 6 | walvis bay
# Processing Record 27 of Set 6 | kulia village
# City not found. Skipping...
# Processing Record 28 of Set 6 | bereket
# Processing Record 29 of Set 6 | port lincoln
# Processing Record 30 of Set 6 | nemuro
# Processing Record 31 of Set 6 | sur
# Processing Record 32 of Set 6 | maracaju
# Processing Record 33 of Set 6 | ghadamis
# Processing Record 34 of Set 6 | mukah
# City not found. Skipping...
# Processing Record 35 of Set 6 | isle of lewis
# City not found. Skipping...
# Processing Record 36 of Set 6 | san blas
# Processing Record 37 of Set 6 | glace bay
# Processing Record 38 of Set 6 | edgewater
# Processing Record 39 of Set 6 | buala
# Processing Record 40 of Set 6 | ocean shores
# Processing Record 41 of Set 6 | naigarhi
# Processing Record 42 of Set 6 | san luis de la loma
# Processing Record 43 of Set 6 | tobi village
# City not found. Skipping...
# Processing Record 44 of Set 6 | roma
# Processing Record 45 of Set 6 | port-gentil
# Processing Record 46 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 47 of Set 6 | kushiro
# Processing Record 48 of Set 6 | kosh-agach
# Processing Record 49 of Set 6 | bhitarwar
# Processing Record 0 of Set 7 | new norfolk
# Processing Record 1 of Set 7 | edd
# Processing Record 2 of Set 7 | pemangkat
# Processing Record 3 of Set 7 | gebeit
# Processing Record 4 of Set 7 | laojunmiao
# Processing Record 5 of Set 7 | katsuura
# Processing Record 6 of Set 7 | alghero
# Processing Record 7 of Set 7 | trairi
# Processing Record 8 of Set 7 | maloyaroslavets
# Processing Record 9 of Set 7 | totness
# Processing Record 10 of Set 7 | oualidia
# City not found. Skipping...
# Processing Record 11 of Set 7 | port glaud
# City not found. Skipping...
# Processing Record 12 of Set 7 | shchyolkino
# Processing Record 13 of Set 7 | talcahuano
# Processing Record 14 of Set 7 | grojec
# Processing Record 15 of Set 7 | ciudad mante
# Processing Record 16 of Set 7 | smithers
# Processing Record 17 of Set 7 | seven pagodas
# Processing Record 18 of Set 7 | chibougamau
# Processing Record 19 of Set 7 | mata-utu
# Processing Record 20 of Set 7 | rach gia
# Processing Record 21 of Set 7 | tofol
# Processing Record 22 of Set 7 | talnakh
# Processing Record 23 of Set 7 | taroa
# Processing Record 24 of Set 7 | mahabe
# City not found. Skipping...
# Processing Record 25 of Set 7 | ad dilam
# Processing Record 26 of Set 7 | porto novo
# Processing Record 27 of Set 7 | humaita
# Processing Record 28 of Set 7 | sultanah
# Processing Record 29 of Set 7 | elmendorf air force base
# City not found. Skipping...
# Processing Record 30 of Set 7 | iwanai
# Processing Record 31 of Set 7 | astrakhan
# Processing Record 32 of Set 7 | codrington
# Processing Record 33 of Set 7 | ayr
# Processing Record 34 of Set 7 | hotan
# Processing Record 35 of Set 7 | shache
# Processing Record 36 of Set 7 | afaahiti
# Processing Record 37 of Set 7 | zlynka
# Processing Record 38 of Set 7 | chilecito
# Processing Record 39 of Set 7 | okoneshnikovo
# Processing Record 40 of Set 7 | berlin
# Processing Record 41 of Set 7 | westport
# Processing Record 42 of Set 7 | lihue
# Processing Record 43 of Set 7 | ust'-uda
# Processing Record 44 of Set 7 | vadso
# Processing Record 45 of Set 7 | udachny
# Processing Record 46 of Set 7 | turpan
# Processing Record 47 of Set 7 | mareno di piave
# Processing Record 48 of Set 7 | acajutla
# Processing Record 49 of Set 7 | ishigaki
# Processing Record 0 of Set 8 | calatayud
# Processing Record 1 of Set 8 | port alfred
# Processing Record 2 of Set 8 | nguigmi
# Processing Record 3 of Set 8 | neyshabur
# Processing Record 4 of Set 8 | taro
# Processing Record 5 of Set 8 | pauini
# Processing Record 6 of Set 8 | olinda
# Processing Record 7 of Set 8 | roccella ionica
# Processing Record 8 of Set 8 | nagqu
# Processing Record 9 of Set 8 | goz beida
# Processing Record 10 of Set 8 | lautoka
# Processing Record 11 of Set 8 | irituia
# Processing Record 12 of Set 8 | bosansko grahovo
# Processing Record 13 of Set 8 | severo-yeniseyskiy
# Processing Record 14 of Set 8 | gadzhiyevo
# Processing Record 15 of Set 8 | port hedland
# Processing Record 16 of Set 8 | chishmy
# Processing Record 17 of Set 8 | rock springs
# Processing Record 18 of Set 8 | kokstad
# Processing Record 19 of Set 8 | haifa
# Processing Record 20 of Set 8 | waynesboro
# Processing Record 21 of Set 8 | masterton
# Processing Record 22 of Set 8 | praia
# Processing Record 23 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 24 of Set 8 | ixtapa
# Processing Record 25 of Set 8 | dwarka
# Processing Record 26 of Set 8 | lorengau
# Processing Record 27 of Set 8 | vilyuysk
# Processing Record 28 of Set 8 | flexeiras
# Processing Record 29 of Set 8 | bayan
# Processing Record 30 of Set 8 | hualien city
# Processing Record 31 of Set 8 | ta`u
# Processing Record 32 of Set 8 | axim
# Processing Record 33 of Set 8 | badger
# Processing Record 34 of Set 8 | vernon
# Processing Record 35 of Set 8 | palamos
# Processing Record 36 of Set 8 | tolanaro
# Processing Record 37 of Set 8 | buurhakaba
# Processing Record 38 of Set 8 | kolda
# Processing Record 39 of Set 8 | yigo village
# Processing Record 40 of Set 8 | donji vakuf
# Processing Record 41 of Set 8 | hovd
# Processing Record 42 of Set 8 | piet retief
# Processing Record 43 of Set 8 | jiwani
# Processing Record 44 of Set 8 | susuman
# Processing Record 45 of Set 8 | flin flon
# Processing Record 46 of Set 8 | yaren
# Processing Record 47 of Set 8 | kununurra
# Processing Record 48 of Set 8 | shahdad kot
# Processing Record 49 of Set 8 | ponta delgada
# Processing Record 0 of Set 9 | palopo
# Processing Record 1 of Set 9 | sihanoukville
# Processing Record 2 of Set 9 | aioun
# Processing Record 3 of Set 9 | yeraliyev
# Processing Record 4 of Set 9 | nikolayevsk-on-amure
# Processing Record 5 of Set 9 | picos
# Processing Record 6 of Set 9 | san andres
# Processing Record 7 of Set 9 | east ballina
# Processing Record 8 of Set 9 | chizhou
# Processing Record 9 of Set 9 | sunbury
# Processing Record 10 of Set 9 | azemmour
# Processing Record 11 of Set 9 | natal
# Processing Record 12 of Set 9 | solnechnyy
# Processing Record 13 of Set 9 | huntingburg
# Processing Record 14 of Set 9 | lyantor
# Processing Record 15 of Set 9 | nuuk
# Processing Record 16 of Set 9 | akdagmadeni
# Processing Record 17 of Set 9 | kristiansund
# Processing Record 18 of Set 9 | weno
# Processing Record 19 of Set 9 | tual
# Processing Record 20 of Set 9 | kourou
# Processing Record 21 of Set 9 | waingapu
# Processing Record 22 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 23 of Set 9 | sangin
# Processing Record 24 of Set 9 | zhelezinka
# Processing Record 25 of Set 9 | ambato boeny
# Processing Record 26 of Set 9 | hayma'
# City not found. Skipping...
# Processing Record 27 of Set 9 | glendive
# Processing Record 28 of Set 9 | bakanas
# Processing Record 29 of Set 9 | juneau
# Processing Record 30 of Set 9 | tlahualilo de zaragoza
# Processing Record 31 of Set 9 | thai binh
# Processing Record 32 of Set 9 | tazacorte
# Processing Record 33 of Set 9 | katsuren-haebaru
# Processing Record 34 of Set 9 | verkhniy rohachyk
# Processing Record 35 of Set 9 | mikomeseng
# Processing Record 36 of Set 9 | igrim
# Processing Record 37 of Set 9 | shingu
# Processing Record 38 of Set 9 | touros
# Processing Record 39 of Set 9 | kisi
# Processing Record 40 of Set 9 | gorontalo
# Processing Record 41 of Set 9 | isangel
# Processing Record 42 of Set 9 | yabelo
# Processing Record 43 of Set 9 | platteville
# Processing Record 44 of Set 9 | joutseno
# Processing Record 45 of Set 9 | barra
# Processing Record 46 of Set 9 | la'ie
# Processing Record 47 of Set 9 | ilhabela
# Processing Record 48 of Set 9 | aq qayeh
# City not found. Skipping...
# Processing Record 49 of Set 9 | tiverton
# Processing Record 0 of Set 10 | rukban
# City not found. Skipping...
# Processing Record 1 of Set 10 | ituango
# Processing Record 2 of Set 10 | mhamid
# Processing Record 3 of Set 10 | dubbo
# Processing Record 4 of Set 10 | tromso
# Processing Record 5 of Set 10 | kirensk
# Processing Record 6 of Set 10 | koneurgench
# City not found. Skipping...
# Processing Record 7 of Set 10 | kalashnikovo
# Processing Record 8 of Set 10 | greymouth
# Processing Record 9 of Set 10 | cannonvale
# Processing Record 10 of Set 10 | el granada
# Processing Record 11 of Set 10 | matthew town
# Processing Record 12 of Set 10 | kemijarvi
# Processing Record 13 of Set 10 | maymana
# Processing Record 14 of Set 10 | nkhotakota
# Processing Record 15 of Set 10 | el calafate
# Processing Record 16 of Set 10 | newman
# Processing Record 17 of Set 10 | tsiombe
# Processing Record 18 of Set 10 | arrifes
# Processing Record 19 of Set 10 | orchard homes
# Processing Record 20 of Set 10 | khailar
# Processing Record 21 of Set 10 | aktau
# Processing Record 22 of Set 10 | kushk
# Processing Record 23 of Set 10 | xiaoweizhai
# Processing Record 24 of Set 10 | saratamata
# City not found. Skipping...
# Processing Record 25 of Set 10 | happy valley-goose bay
# Processing Record 26 of Set 10 | kani keli
# Processing Record 27 of Set 10 | san julian
# Processing Record 28 of Set 10 | uzice
# Processing Record 29 of Set 10 | espargos
# City not found. Skipping...
# Processing Record 30 of Set 10 | gemena
# Processing Record 31 of Set 10 | malax
# Processing Record 32 of Set 10 | colotlan
# Processing Record 33 of Set 10 | marsa alam
# Processing Record 34 of Set 10 | makoua
# Processing Record 35 of Set 10 | inarajan village
# Processing Record 36 of Set 10 | obo
# Processing Record 37 of Set 10 | musay'id
# City not found. Skipping...
# Processing Record 38 of Set 10 | sandnessjoen
# Processing Record 39 of Set 10 | mount pearl
# Processing Record 40 of Set 10 | byron bay
# Processing Record 41 of Set 10 | kindu
# Processing Record 42 of Set 10 | afif
# Processing Record 43 of Set 10 | ataq
# Processing Record 44 of Set 10 | khairpur nathan shah
# Processing Record 45 of Set 10 | manaure
# Processing Record 46 of Set 10 | tulun
# Processing Record 47 of Set 10 | cuito
# Processing Record 48 of Set 10 | rakops
# Processing Record 49 of Set 10 | nenjiang
# Processing Record 0 of Set 11 | arish
# Processing Record 1 of Set 11 | pavlovsk
# Processing Record 2 of Set 11 | tianpeng
# Processing Record 3 of Set 11 | upington
# Processing Record 4 of Set 11 | churapcha
# Processing Record 5 of Set 11 | fisterra
# Processing Record 6 of Set 11 | rumuruti
# Processing Record 7 of Set 11 | opuwo
# Processing Record 8 of Set 11 | kayangel
# Processing Record 9 of Set 11 | kaitong
# Processing Record 10 of Set 11 | port macquarie
# Processing Record 11 of Set 11 | hammerfest
# Processing Record 12 of Set 11 | maclovio rojas
# City not found. Skipping...
# Processing Record 13 of Set 11 | kanniyakumari
# Processing Record 14 of Set 11 | yanaul
# Processing Record 15 of Set 11 | port augusta
# Processing Record 16 of Set 11 | turgen
# Processing Record 17 of Set 11 | withernsea
# Processing Record 18 of Set 11 | peace river
# Processing Record 19 of Set 11 | biltine
# Processing Record 20 of Set 11 | palmer
# Processing Record 21 of Set 11 | saint-pierre-d'oleron
# City not found. Skipping...
# Processing Record 22 of Set 11 | sierra grande
# Processing Record 23 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 24 of Set 11 | nejo
# Processing Record 25 of Set 11 | massakory
# Processing Record 26 of Set 11 | rio grande
# Processing Record 27 of Set 11 | nikel
# Processing Record 28 of Set 11 | pradopolis
# Processing Record 29 of Set 11 | golaghat
# Processing Record 30 of Set 11 | ostersund
# Processing Record 31 of Set 11 | tranovaho
# City not found. Skipping...
# Processing Record 32 of Set 11 | uray
# Processing Record 33 of Set 11 | kotido
# Processing Record 34 of Set 11 | prince rupert
# Processing Record 35 of Set 11 | port saint john's
# Processing Record 36 of Set 11 | una
# Processing Record 37 of Set 11 | djamaa
# Processing Record 38 of Set 11 | dali
# Processing Record 39 of Set 11 | hanceville
# Processing Record 40 of Set 11 | brookings
# Processing Record 41 of Set 11 | boa vista
# Processing Record 42 of Set 11 | karratha
# Processing Record 43 of Set 11 | saint croix
# Processing Record 44 of Set 11 | haimen
# Processing Record 45 of Set 11 | dossor
# Processing Record 46 of Set 11 | mulayjah
# Processing Record 47 of Set 11 | broome
# Processing Record 48 of Set 11 | guatrache
# Processing Record 49 of Set 11 | constitucion
# Processing Record 0 of Set 12 | antsohihy
# Processing Record 1 of Set 12 | port pirie
# Processing Record 2 of Set 12 | lata
# Processing Record 3 of Set 12 | troitsko-pechorsk
# Processing Record 4 of Set 12 | fauske
# Processing Record 5 of Set 12 | chepo
# Processing Record 6 of Set 12 | pavlovka
# Processing Record 7 of Set 12 | yuzhno-kurilsk
# Processing Record 8 of Set 12 | puerto santa
# Processing Record 9 of Set 12 | qarqaraly
# Processing Record 10 of Set 12 | eirunepe
# Processing Record 11 of Set 12 | cockburn town
# Processing Record 12 of Set 12 | derzhavinsk
# Processing Record 13 of Set 12 | hit
# Processing Record 14 of Set 12 | the pas
# Processing Record 15 of Set 12 | alipur duar
# City not found. Skipping...
# Processing Record 16 of Set 12 | al hayy
# Processing Record 17 of Set 12 | jian'ou
# Processing Record 18 of Set 12 | santa cruz
# Processing Record 19 of Set 12 | richards bay
# Processing Record 20 of Set 12 | illizi
# Processing Record 21 of Set 12 | diplo
# Processing Record 22 of Set 12 | sarh
# Processing Record 23 of Set 12 | nimaparha
# Processing Record 24 of Set 12 | gbarnga
# Processing Record 25 of Set 12 | ceeldheer
# Processing Record 26 of Set 12 | hono
# Processing Record 27 of Set 12 | prince george
# Processing Record 28 of Set 12 | beloyarskiy
# Processing Record 29 of Set 12 | aras-asan
# Processing Record 30 of Set 12 | togur
# Processing Record 31 of Set 12 | arteche
# Processing Record 32 of Set 12 | ulaangom
# Processing Record 33 of Set 12 | tsetserleg
# Processing Record 34 of Set 12 | hilo
# Processing Record 35 of Set 12 | hobyo
# Processing Record 36 of Set 12 | medicine hat
# Processing Record 37 of Set 12 | shetpe
# Processing Record 38 of Set 12 | fort bragg
# Processing Record 39 of Set 12 | al jawf
# Processing Record 40 of Set 12 | den burg
# Processing Record 41 of Set 12 | macapa
# Processing Record 42 of Set 12 | ugoofaaru
# Processing Record 43 of Set 12 | kasimov
# Processing Record 44 of Set 12 | yamada
# Processing Record 45 of Set 12 | tazovsky
# Processing Record 46 of Set 12 | jiayuguan
# Processing Record 47 of Set 12 | fuglafjordur
# Processing Record 48 of Set 12 | ambodifotatra
# Processing Record 49 of Set 12 | dudinka
# Processing Record 0 of Set 13 | taoudenni
# Processing Record 1 of Set 13 | arkadelphia
# Processing Record 2 of Set 13 | bogdanovich
# Processing Record 3 of Set 13 | coyhaique
# Processing Record 4 of Set 13 | ondjiva
# Processing Record 5 of Set 13 | gobabis
# Processing Record 6 of Set 13 | felidhoo
# City not found. Skipping...
# Processing Record 7 of Set 13 | hadibu
# Processing Record 8 of Set 13 | al fuwayliq
# Processing Record 9 of Set 13 | acapulco de juarez
# Processing Record 10 of Set 13 | chui
# Processing Record 11 of Set 13 | andovoranto
# Processing Record 12 of Set 13 | pimentel
# Processing Record 13 of Set 13 | new castle
# Processing Record 14 of Set 13 | burley
# Processing Record 15 of Set 13 | tarawa
# Processing Record 16 of Set 13 | marsh harbour
# Processing Record 17 of Set 13 | antalaha
# Processing Record 18 of Set 13 | beni
# Processing Record 19 of Set 13 | boguchany
# Processing Record 20 of Set 13 | mandera
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          584
# Lat           584
# Lng           584
# Max Temp      584
# Humidity      584
# Cloudiness    584
# Wind Speed    584
# Country       584
# Date          584
# dtype: int64

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           queenstown -31.8976   26.8753     15.14        82         100
# 1       mont-tremblant  46.1949  -74.6264      7.77        36          86
# 2  fale old settlement  -9.3852 -171.2468     29.35        76          17
# 3              vorkuta  67.5000   64.0000    -11.41        96         100
# 4            adamstown -25.0660 -130.1015     23.76        70         100
# 5        blackmans bay -43.0167  147.3167     13.62        90          28
# 6              chonchi -42.6128  -73.8092     14.56        62          46
# 7               luanda  -8.8368   13.2343     26.00        83          75
# 8         invercargill -46.4000  168.3500     10.01        95          91
# 9           cottonwood  34.7392 -112.0099     20.79        29          12
#
#    Wind Speed Country        Date
# 0        3.76      ZA  1711737017
# 1        2.06      CA  1711736609
# 2        4.90      TK  1711737022
# 3        4.22      RU  1711737048
# 4       12.39      PN  1711737022
# 5        1.49      AU  1711737005
# 6        3.25      CL  1711737057
# 7        1.54      AO  1711736933
# 8        3.03      NZ  1711736946
# 9        4.47      US  1711736977

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                 queenstown -31.8976   26.8753     15.14        82
# 1             mont-tremblant  46.1949  -74.6264      7.77        36
# 2        fale old settlement  -9.3852 -171.2468     29.35        76
# 3                    vorkuta  67.5000   64.0000    -11.41        96
# 4                  adamstown -25.0660 -130.1015     23.76        70
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        3.76      ZA  1711737017
# 1                86        2.06      CA  1711736609
# 2                17        4.90      TK  1711737022
# 3               100        4.22      RU  1711737048
# 4               100       12.39      PN  1711737022

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
latitudes = city_data_df["Lat"]
temp = city_data_df["Max Temp"]
#date = pd.to_datetime(city_data_df['Date'])
plt.scatter(latitudes,temp, marker = 'o', facecolors= 'blue', alpha = .75)
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Latitude vs. Max Temperature (2020-10-18)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
humidity = city_data_df["Humidity"]
plt.scatter(latitudes,humidity, marker = 'o', facecolors= 'blue', alpha = .75)
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity (2022-10-18)')
plt.grid()
# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
cloud = city_data_df["Cloudiness"]
plt.scatter(latitudes,cloud, marker = 'o', facecolors= 'blue', alpha = .75)
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness (2022-10-18)')
plt.grid()
# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
windspeed = city_data_df["Wind Speed"]
plt.scatter(latitudes,windspeed, marker = 'o', facecolors= 'blue', alpha = .75)
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind speed')
plt.title('City Latitude vs. Windspeed (2022-10-18)')
plt.grid()
# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linreg(x,y):
    slope, int, r, p, std_err = stats.linregress(x,y)
    fit = slope*x + int
    return fit , slope, int, r, p ,std_err

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df['Lat']>=0), :]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        mont-tremblant  46.1949  -74.6264      7.77        36          86
# 3               vorkuta  67.5000   64.0000    -11.41        96         100
# 9            cottonwood  34.7392 -112.0099     20.79        29          12
# 13          vilyuchinsk  52.9306  158.4028     -7.82        77           3
# 16             hamilton  39.1834  -84.5333     20.50        38          20
#
#          Wind Speed Country        Date
# City_ID
# 1              2.06      CA  1711736609
# 3              4.22      RU  1711737048
# 9              4.47      US  1711736977
# 13             2.68      RU  1711737091
# 16             7.72      US  1711736643

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df['Lat'] < 0), :]
# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                 queenstown -31.8976   26.8753     15.14        82
# 2        fale old settlement  -9.3852 -171.2468     29.35        76
# 4                  adamstown -25.0660 -130.1015     23.76        70
# 5              blackmans bay -43.0167  147.3167     13.62        90
# 6                    chonchi -42.6128  -73.8092     14.56        62
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        3.76      ZA  1711737017
# 2                17        4.90      TK  1711737022
# 4               100       12.39      PN  1711737022
# 5                28        1.49      AU  1711737005
# 6                46        3.25      CL  1711737057

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
linreg(latitude_north, northern_hemi_df['Max Temp'])
# Out:
# (City_ID
#  1       7.133703
#  3      -6.302578
#  9      14.358358
#  13      2.885764
#  16     11.555578
#           ...
#  578    35.372086
#  579    19.528512
#  581    35.951663
#  582    -0.551839
#  583    33.784336
#  Name: Lat, Length: 415, dtype: float64,
#  -0.6306603095402034,
#  36.266993072957504,
#  -0.8765392543992839,
#  3.1600078740742512e-133,
#  0.01704089412887841)

# %%
# Linear regression on Northern Hemisphere
latitude_north = northern_hemi_df['Lat']
a,b,c,d,e,f = linreg(latitude_north, northern_hemi_df['Max Temp'])
plt.scatter(latitude_north,northern_hemi_df['Max Temp'], marker = 'o', facecolors= 'blue', alpha = .75)
plt.plot(latitude_north,a, color = 'r') 
line_eq = f"y = {str(round(b,2))}x + {str(round(c,2))}"
plt.annotate(line_eq,(5.8,0.8))
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('Northern Hemisphere Latitude vs. Max Temperature (2020-10-18)')
plt.grid()

# %%
# Linear regression on Southern Hemisphere
latitude_south = southern_hemi_df['Lat']
a,b,c,d,e,f = linreg(latitude_south, southern_hemi_df['Max Temp'])
plt.scatter(latitude_south,southern_hemi_df['Max Temp'], marker = 'o', facecolors= 'blue', alpha = .75)
plt.plot(latitude_south,a, color = 'r') 
line_eq_south = f"y = {str(round(b,2))}x + {str(round(c,2))}"
plt.annotate(line_eq_south,(-10.8,0.8))
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('Southern Hemisphere Latitude vs. Max Temperature (2020-10-18)')
plt.grid()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
